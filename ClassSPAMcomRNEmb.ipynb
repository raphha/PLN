# %% [markdown]
# <a href="https://colab.research.google.com/github/raphha/PLN/blob/main/ClassSPAMcomRNEmb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding
from google.colab import files

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
files.upload()

# %%
spam = pd.read_csv("spam.csv")
spam.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(spam['Category'])
print(y)
# Out:
# [0 0 1 ... 0 0 0]

# %%
mensagens = spam['Message'].values
X_train, X_test, y_train, y_test = train_test_split(mensagens, y, test_size=0.3)

# %%
token = Tokenizer(num_words=1000)
token.fit_on_texts(X_train)

X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# %%
print(X_train)
# Out:
# [[177, 39, 21, 317, 2, 229, 6, 598, 335, 446, 20, 3, 17, 202, 4, 162, 283, 16, 46, 634, 336, 133, 484, 671, 66], [131, 67, 17, 58, 384], [59, 672, 265, 9, 44, 41, 90], [59, 25, 52, 93, 6, 159, 93, 6, 163, 52, 63, 34, 68, 25, 193, 10, 140, 6, 174, 117, 6, 284, 85, 31, 26, 35, 14, 19, 223], [317, 715, 19, 6, 352, 147, 39, 429], [96, 567, 179, 122, 12, 106, 7, 568], [136, 12, 10, 70, 8, 37, 239, 18, 858, 209, 1, 32, 140, 11, 7, 94, 3], [49, 56, 1, 32, 54, 2, 34, 77, 164, 385, 125, 415], [136, 25, 599, 5, 400, 40, 416], [95, 294, 5, 285, 533, 207, 18, 34, 95, 154, 19, 65, 2, 12, 5, 533, 39, 401, 71, 6, 4, 48], [337, 485, 42, 12, 858, 7, 57, 4, 513, 19, 1, 189, 23, 28, 673, 59, 26, 465, 635, 15], [86, 86, 59, 58, 43, 21, 3, 76], [], [787, 199, 180, 3, 240, 240, 514, 430, 1, 61, 128, 1, 38, 69, 2, 53, 20, 3, 21, 486, 286, 151, 35, 314, 5, 930, 15, 13, 68], [3, 53, 11, 569, 1, 269, 3, 87, 513, 200, 295, 8, 67, 61, 9, 788, 29, 10, 179, 122, 7, 447, 10, 2, 165, 114, 85, 28, 22, 534], [37, 74, 2, 84, 145, 535, 338, 270, 15, 40], [31, 39, 166, 59, 152, 37, 116, 789, 12, 318, 64], [59, 58, 2, 353, 46, 3], [58, 197, 190, 126, 1, 319, 515, 6, 42], [37, 119, 320, 246, 137, 716, 15, 241, 18, 24, 174, 7, 134, 184, 2, 339], [3, 21, 4, 167, 167, 167, 167, 354, 320, 24], [178], [51, 64, 3, 97, 859, 17, 14, 74, 2, 53, 43, 1, 132, 33], [8, 20, 8, 26], [271, 303, 2, 6, 32, 33, 15, 55, 5, 321, 536, 7, 790, 71, 36, 91, 2], [1, 270, 84, 791, 47, 77, 80, 931, 181, 78, 185, 76, 50, 402, 45, 11], [300, 30, 48], [417, 45, 10, 77], [932, 30, 79, 9, 5], [117, 3, 5, 431, 21, 3, 125, 117, 3, 137, 4, 21, 3, 13, 418, 216, 403, 35, 3, 189, 11, 62], [21, 6, 8, 70, 674, 70], [51, 355, 94, 10, 1, 224, 2, 792], [4, 2, 13, 123, 100, 180, 3, 27, 169, 257, 570, 235, 186, 717], [86, 86, 30, 169, 272, 43, 32, 3, 5, 793], [1, 191, 175, 5, 98, 154, 19, 104, 71, 4, 148], [51, 64, 35, 6, 
#  [ 59 672 265 ...   0   0   0]
#  ...
#  [462  31  14 ...   0   0   0]
#  [835 357  39 ...   0   0   0]
#  [413  14 730 ...   0   0   0]]

# %%
print(len(token.word_index))
# Out:
# 7470

# %%
modelo = Sequential()
modelo.add(Embedding(input_dim=len(token.word_index), output_dim=50))
modelo.add(Flatten())

modelo.add(Dense(units=10,activation="relu"))
modelo.add(Dropout(0.1))
modelo.add(Dense(units=1,activation="sigmoid"))

# %%
modelo.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])
modelo.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo.fit(X_train, y_train,epochs=20,batch_size=10, verbose=True, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8647 - loss: 0.1045 - val_accuracy: 0.9713 - val_loss: 0.0411
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9800 - loss: 0.0408 - val_accuracy: 0.9827 - val_loss: 0.0311
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9853 - loss: 0.0313 - val_accuracy: 0.9839 - val_loss: 0.0257
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9888 - loss: 0.0144 - val_accuracy: 0.9839 - val_loss: 0.0136
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9913 - loss: 0.0081 - val_accuracy: 0.9862 - val_loss: 0.0123
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9937 - loss: 0.0066 - val_accuracy: 0.9856 - val_loss: 0.0117
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9965 - loss: 0.0045 - val_accuracy: 0.9850 - val_loss: 0.0131
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9977 - loss: 0.0034 - val_accuracy: 0.9868 - val_loss: 0.0109
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9958 - loss: 0.0045 - val_accuracy: 0.9856 - val_loss: 0.0119
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9959 - loss: 0.0053 - val_accuracy: 0.9839 - val_loss: 0.0124
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9971 - loss: 0.0042 - val_accuracy: 0.9862 - val_loss: 0.0120
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9958 - loss: 0.0043 - val_accuracy: 0.9856 - val_loss: 0.0125
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9928 - loss: 0.0075 - val_accuracy: 0.9850 - val_loss: 0.0126
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9965 - loss: 0.0041 - val_accuracy: 0.9635 - val_loss: 0.0331
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9717 - loss: 0.0238 - val_accuracy: 0.9850 - val_loss: 0.0132
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9968 - loss: 0.0034 - val_accuracy: 0.9839 - val_loss: 0.0127
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9971 - loss: 0.0028 - val_accuracy: 0.9850 - val_loss: 0.0135
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9967 - loss: 0.0032 - val_accuracy: 0.9856 - val_loss: 0.0130
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9950 - loss: 0.0043 - val_accuracy: 0.9856 - val_loss: 0.0130
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9957 - loss: 0.0037 - val_accuracy: 0.9856 - val_loss: 0.0130

# %%
loss, accuracy = modelo.evaluate(X_test,y_test)
print("Loss: ", loss)
print("Acurácia: ", accuracy)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0122
# Loss:  0.013044917024672031
# Acurácia:  0.9856459498405457

# %%
nova_previsao = modelo.predict(X_test)
print(nova_previsao)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[9.9994051e-01]
#  [2.8930788e-06]
#  [2.9425061e-15]
#  ...
#  [2.6659618e-14]
#  [1.0000000e+00]
#  [1.7489796e-11]]

# %%
prev = (nova_previsao > 0.5)
print(prev)
# Out:
# [[ True]
#  [False]
#  [False]
#  ...
#  [False]
#  [ True]
#  [False]]

# %%
cm = confusion_matrix(y_test, prev)
print(cm)
# Out:
# [[1448   11]
#  [  13  200]]
